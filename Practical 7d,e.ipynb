# %% [markdown]
# Using iris.csv

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# Load dataset
iris = load_iris()

X = iris.data
y = iris.target

# Create classification model
model = KNeighborsClassifier()

# Apply 5-fold cross-validation
scores = cross_val_score(model, X, y, cv=5)

print("Accuracy scores for each fold:")
print(scores)

print("Average Accuracy:", round(scores.mean() * 100, 2), "%")
# Out:
# Accuracy scores for each fold:
# [0.96666667 1.         0.93333333 0.96666667 1.        ]
# Average Accuracy: 97.33 %

# %% [markdown]
# Using wine.csv

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# Load dataset
wine = pd.read_csv("wine.csv")

# Features and Target
X = wine.iloc[:, :-1]
y = wine.iloc[:, -1]

# Create classification model
model = KNeighborsClassifier()

# Apply 5-fold cross-validation
scores = cross_val_score(model, X, y, cv=5)

print("Accuracy scores for each fold:")
print(scores)

print("Average Accuracy:", round(scores.mean() * 100, 2), "%")
# Out:
# Accuracy scores for each fold:
# [0.72222222 0.66666667 0.63888889 0.65714286 0.77142857]
# Average Accuracy: 69.13 %

# %% [markdown]
# Using iris.csv

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# Load dataset
iris = load_iris()

X = iris.data
y = iris.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=1
)

# Create model
model = DecisionTreeClassifier()

# Train model
model.fit(X_train, y_train)

# Display accuracy
print("Training Accuracy:", model.score(X_train, y_train) * 100)
print("Testing Accuracy:", model.score(X_test, y_test) * 100)

# Prediction
prediction = model.predict([X_test[0]])
print("Predicted Class:", prediction[0])
# Out:
# Training Accuracy: 100.0
# Testing Accuracy: 95.55555555555556
# Predicted Class: 0

# %% [markdown]
# Using wine.csv

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# Load dataset
wine = pd.read_csv("wine.csv")

# Features and Target
X = wine.iloc[:, :-1]
y = wine.iloc[:, -1]

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=1
)

# Create model
model = DecisionTreeClassifier()

# Train model
model.fit(X_train, y_train)

# Display accuracy
print("Training Accuracy:", model.score(X_train, y_train) * 100)
print("Testing Accuracy:", model.score(X_test, y_test) * 100)

# Prediction
prediction = model.predict([X_test.iloc[0]])
print("Predicted Class:", prediction[0])
# Out:
# Training Accuracy: 100.0
# Testing Accuracy: 94.44444444444444
# Predicted Class: 2
# C:\Users\sachin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
